# %%
from edmacro import *
from edmacro import _extras as ext
import time
import os
import matplotlib.pyplot as plt

# %%
resolutions = [(1280, 720), (1024, 768), (1366, 768), (1600, 900), (1920, 1080)]

import os 
import sys

sys.path.append(os.path.join(os.getcwd(), "edmacro"))
os.chdir(os.path.join(os.getcwd(), "edmacro")) 


from edmacro import *

mc = MacroController()


for res in resolutions:
    ext.change_monitor_resolution(*res)
    time.sleep(5)
    utils.activate_roblox()
    mc = MacroController()
    mc.current_map = (2, 0)
    mc.boss_run.restart_char()
    mc.boss_run.execute(repeat=1, target_boss="KINGSLIME")
# Out:
# 2024-04-21 19:49:31.229 | DEBUG    | edmacro:__init__:32 - Config loaded
# 2024-04-21 19:49:31.234 | INFO     | edmacro:__init__:42 - MacroController initialized
# 2024-04-21 19:49:31.245 | DEBUG    | edmacro:__load_assets:69 - Loaded 28 assets.
# 2024-04-21 19:49:31.247 | INFO     | edmacro:__init__:45 - Assets loaded
# 2024-04-21 19:49:39.483 | DEBUG    | edmacro:__init__:32 - Config loaded
# 2024-04-21 19:49:39.488 | INFO     | edmacro:__init__:42 - MacroController initialized
# 2024-04-21 19:49:39.503 | DEBUG    | edmacro:__load_assets:69 - Loaded 28 assets.
# 2024-04-21 19:49:39.506 | INFO     | edmacro:__init__:45 - Assets loaded
# 2024-04-21 19:49:39.512 | INFO     | edmacro.actions:restart_char:53 - Restarting character
# 2024-04-21 19:49:44.726 | INFO     | edmacro.actions.boss_run:execute:66 - Running boss 1 times
# 2024-04-21 19:49:44.941 | INFO     | edmacro.actions.boss_run:__go_to_kingslime_boss:262 - Going to Slime boss
# 2024-04-21 19:49:55.436 | INFO     | edmacro.actions.boss_run:execute:102 - Clicking on respawn button
# 2024-04-21 19:49:56.892 | INFO     | edmacro.actions.boss_run:execute:119 - clicked on start button
# 2024-04-21 19:50:06.894 | INFO     | edmacro.actions.boss_run:__freeze_game:324 - Freezing game for 6.405833333333334
# 2024-04-21 19:50:14.138 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9071738123893738 of confidence, freezing game again
# 2024-04-21 19:50:15.271 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9071342945098877 of confidence, freezing game again
# 2024-04-21 19:50:16.403 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9068846106529236 of confidence, freezing game again
# 2024-04-21 19:50:17.522 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9069018959999084 of confidence, freezing game again
# 2024-04-21 19:50:18.656 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9068418741226196 of confidence, freezing game again
# 2024-04-21 19:50:19.788 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.906803548336029 of confidence, freezing game again
# 2024-04-21 19:50:20.918 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9066643714904785 of confidence, freezing game again
# 2024-04-21 19:50:22.049 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9068084359169006 of confidence, freezing game again
# 2024-04-21 19:50:23.386 | INFO     | edmacro.actions.boss_run:execute:125 - Boss run 1 finished. Took 38.6580867767334 seconds
# 2024-04-21 19:50:39.331 | INFO     | edmacro.actions.boss_run:execute:151 - Boss run finished. Total time: 38.66 s, Average time: 38.66 s
# 2024-04-21 19:50:45.703 | DEBUG    | edmacro:__init__:32 - Config loaded
# 2024-04-21 19:50:45.710 | INFO     | edmacro:__init__:42 - MacroController initialized
# 2024-04-21 19:50:45.774 | DEBUG    | edmacro:__load_assets:69 - Loaded 28 assets.
# 2024-04-21 19:50:45.779 | INFO     | edmacro:__init__:45 - Assets loaded
# 2024-04-21 19:50:45.789 | INFO     | edmacro.actions:restart_char:53 - Restarting character
# 2024-04-21 19:50:48.519 | DEBUG    | edmacro.actions:restart_char:64 - The player wasnt respawned in the teleporter. Lets open the map and teleport him to same place.
# 2024-04-21 19:50:53.525 | INFO     | edmacro.actions:open_map:120 - Opened map
# 2024-04-21 19:50:53.526 | INFO     | edmacro.actions:move_to_map:232 - (2, 0) -> (2, 0): []
# 2024-04-21 19:50:53.531 | INFO     | edmacro.actions:move_to_map:246 - Moved to map 2 column 0
# 2024-04-21 19:50:55.353 | INFO     | edmacro.actions:restart_char:53 - Restarting character
# 2024-04-21 19:51:02.973 | INFO     | edmacro.actions.boss_run:execute:66 - Running boss 1 times
# 2024-04-21 19:51:03.213 | INFO     | edmacro.actions.boss_run:__go_to_kingslime_boss:262 - Going to Slime boss
# 2024-04-21 19:51:13.118 | INFO     | edmacro.actions.boss_run:execute:87 - Clicking on respawn tome
# 2024-04-21 19:51:14.143 | INFO     | edmacro.actions.boss_run:execute:102 - Clicking on respawn button
# 2024-04-21 19:51:15.489 | INFO     | edmacro.actions.boss_run:execute:119 - clicked on start button
# 2024-04-21 19:51:25.492 | INFO     | edmacro.actions.boss_run:__freeze_game:324 - Freezing game for 6.405833333333334
# 2024-04-21 19:51:32.729 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9276512861251831 of confidence, freezing game again
# 2024-04-21 19:51:33.878 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9272237420082092 of confidence, freezing game again
# 2024-04-21 19:51:35.012 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9271852374076843 of confidence, freezing game again
# 2024-04-21 19:51:36.146 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9270488023757935 of confidence, freezing game again
# 2024-04-21 19:51:37.264 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.926907479763031 of confidence, freezing game again
# 2024-04-21 19:51:38.395 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9267372488975525 of confidence, freezing game again
# 2024-04-21 19:51:39.529 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9269022345542908 of confidence, freezing game again
# 2024-04-21 19:51:40.867 | INFO     | edmacro.actions.boss_run:execute:125 - Boss run 1 finished. Took 37.891852617263794 seconds
# 2024-04-21 19:51:56.789 | INFO     | edmacro.actions.boss_run:execute:151 - Boss run finished. Total time: 37.89 s, Average time: 37.89 s
# 2024-04-21 19:52:03.215 | DEBUG    | edmacro:__init__:32 - Config loaded
# 2024-04-21 19:52:03.220 | INFO     | edmacro:__init__:42 - MacroController initialized
# 2024-04-21 19:52:03.237 | DEBUG    | edmacro:__load_assets:69 - Loaded 28 assets.
# 2024-04-21 19:52:03.240 | INFO     | edmacro:__init__:45 - Assets loaded
# 2024-04-21 19:52:03.247 | INFO     | edmacro.actions:restart_char:53 - Restarting character
# 2024-04-21 19:52:05.994 | DEBUG    | edmacro.actions:restart_char:64 - The player wasnt respawned in the teleporter. Lets open the map and teleport him to same place.
# 2024-04-21 19:52:10.998 | INFO     | edmacro.actions:open_map:120 - Opened map
# 2024-04-21 19:52:11.000 | INFO     | edmacro.actions:move_to_map:232 - (2, 0) -> (2, 0): []
# 2024-04-21 19:52:11.009 | INFO     | edmacro.actions:move_to_map:246 - Moved to map 2 column 0
# 2024-04-21 19:52:12.908 | INFO     | edmacro.actions:restart_char:53 - Restarting character
# 2024-04-21 19:52:20.570 | INFO     | edmacro.actions.boss_run:execute:66 - Running boss 1 times
# 2024-04-21 19:52:20.804 | INFO     | edmacro.actions.boss_run:__go_to_kingslime_boss:262 - Going to Slime boss
# 2024-04-21 19:52:30.729 | INFO     | edmacro.actions.boss_run:execute:87 - Clicking on respawn tome
# 2024-04-21 19:52:31.787 | INFO     | edmacro.actions.boss_run:execute:102 - Clicking on respawn button
# 2024-04-21 19:52:33.127 | INFO     | edmacro.actions.boss_run:execute:119 - clicked on start button
# 2024-04-21 19:52:43.129 | INFO     | edmacro.actions.boss_run:__freeze_game:324 - Freezing game for 6.405833333333334
# 2024-04-21 19:52:50.395 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9259365200996399 of confidence, freezing game again
# 2024-04-21 19:52:51.547 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9254039525985718 of confidence, freezing game again
# 2024-04-21 19:52:52.685 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9253647923469543 of confidence, freezing game again
# 2024-04-21 19:52:53.833 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.925268828868866 of confidence, freezing game again
# 2024-04-21 19:52:54.973 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9251328110694885 of confidence, freezing game again
# 2024-04-21 19:52:56.123 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9249461889266968 of confidence, freezing game again
# 2024-04-21 19:52:57.257 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9251784086227417 of confidence, freezing game again
# 2024-04-21 19:52:58.401 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9251062273979187 of confidence, freezing game again
# 2024-04-21 19:52:59.567 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9249531030654907 of confidence, freezing game again
# 2024-04-21 19:53:00.931 | INFO     | edmacro.actions.boss_run:execute:125 - Boss run 1 finished. Took 40.35956168174744 seconds
# 2024-04-21 19:53:16.877 | INFO     | edmacro.actions.boss_run:execute:151 - Boss run finished. Total time: 40.36 s, Average time: 40.36 s
# 2024-04-21 19:53:23.165 | DEBUG    | edmacro:__init__:32 - Config loaded
# 2024-04-21 19:53:23.172 | INFO     | edmacro:__init__:42 - MacroController initialized
# 2024-04-21 19:53:23.192 | DEBUG    | edmacro:__load_assets:69 - Loaded 28 assets.
# 2024-04-21 19:53:23.195 | INFO     | edmacro:__init__:45 - Assets loaded
# 2024-04-21 19:53:23.203 | INFO     | edmacro.actions:restart_char:53 - Restarting character
# 2024-04-21 19:53:25.962 | DEBUG    | edmacro.actions:restart_char:64 - The player wasnt respawned in the teleporter. Lets open the map and teleport him to same place.
# 2024-04-21 19:53:30.966 | INFO     | edmacro.actions:open_map:120 - Opened map
# 2024-04-21 19:53:30.967 | INFO     | edmacro.actions:move_to_map:232 - (2, 0) -> (2, 0): []
# 2024-04-21 19:53:30.980 | INFO     | edmacro.actions:move_to_map:246 - Moved to map 2 column 0
# 2024-04-21 19:53:32.916 | INFO     | edmacro.actions:restart_char:53 - Restarting character
# 2024-04-21 19:53:40.530 | INFO     | edmacro.actions.boss_run:execute:66 - Running boss 1 times
# 2024-04-21 19:53:40.770 | INFO     | edmacro.actions.boss_run:__go_to_kingslime_boss:262 - Going to Slime boss
# 2024-04-21 19:53:50.730 | INFO     | edmacro.actions.boss_run:execute:87 - Clicking on respawn tome
# 2024-04-21 19:53:51.791 | INFO     | edmacro.actions.boss_run:execute:102 - Clicking on respawn button
# 2024-04-21 19:53:53.221 | INFO     | edmacro.actions.boss_run:execute:119 - clicked on start button
# 2024-04-21 19:54:03.223 | INFO     | edmacro.actions.boss_run:__freeze_game:324 - Freezing game for 6.405833333333334
# 2024-04-21 19:54:10.776 | INFO     | edmacro.actions.boss_run:execute:125 - Boss run 1 finished. Took 30.24377179145813 seconds
# 2024-04-21 19:54:26.784 | INFO     | edmacro.actions.boss_run:execute:151 - Boss run finished. Total time: 30.24 s, Average time: 30.24 s
# 2024-04-21 19:54:33.210 | DEBUG    | edmacro:__init__:32 - Config loaded
# 2024-04-21 19:54:33.216 | INFO     | edmacro:__init__:42 - MacroController initialized
# 2024-04-21 19:54:33.236 | DEBUG    | edmacro:__load_assets:69 - Loaded 28 assets.
# 2024-04-21 19:54:33.240 | INFO     | edmacro:__init__:45 - Assets loaded
# 2024-04-21 19:54:33.247 | INFO     | edmacro.actions:restart_char:53 - Restarting character
# 2024-04-21 19:54:36.094 | DEBUG    | edmacro.actions:restart_char:64 - The player wasnt respawned in the teleporter. Lets open the map and teleport him to same place.
# 2024-04-21 19:54:41.100 | INFO     | edmacro.actions:open_map:120 - Opened map
# 2024-04-21 19:54:41.101 | INFO     | edmacro.actions:move_to_map:232 - (2, 0) -> (2, 0): []
# 2024-04-21 19:54:41.117 | INFO     | edmacro.actions:move_to_map:246 - Moved to map 2 column 0
# 2024-04-21 19:54:43.153 | INFO     | edmacro.actions:restart_char:53 - Restarting character
# 2024-04-21 19:54:50.762 | INFO     | edmacro.actions.boss_run:execute:66 - Running boss 1 times
# 2024-04-21 19:54:51.007 | INFO     | edmacro.actions.boss_run:__go_to_kingslime_boss:262 - Going to Slime boss
# 2024-04-21 19:55:01.739 | INFO     | edmacro.actions.boss_run:execute:102 - Clicking on respawn button
# 2024-04-21 19:55:03.227 | INFO     | edmacro.actions.boss_run:execute:119 - clicked on start button
# 2024-04-21 19:55:13.228 | INFO     | edmacro.actions.boss_run:__freeze_game:324 - Freezing game for 6.405833333333334
# 2024-04-21 19:55:20.726 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 1.0 of confidence, freezing game again
# 2024-04-21 19:55:21.955 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 1.0 of confidence, freezing game again
# 2024-04-21 19:55:23.200 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 1.0 of confidence, freezing game again
# 2024-04-21 19:55:24.430 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 1.0 of confidence, freezing game again
# 2024-04-21 19:55:25.671 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9999995827674866 of confidence, freezing game again
# 2024-04-21 19:55:26.900 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9999995827674866 of confidence, freezing game again
# 2024-04-21 19:55:28.129 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 0.9999995827674866 of confidence, freezing game again
# 2024-04-21 19:55:29.384 | WARNING  | edmacro.actions.boss_run:__freeze_game:357 - Boss still alive with 1.0 of confidence, freezing game again
# 2024-04-21 19:55:30.844 | INFO     | edmacro.actions.boss_run:execute:125 - Boss run 1 finished. Took 40.08009934425354 seconds
# 2024-04-21 19:55:46.944 | INFO     | edmacro.actions.boss_run:execute:151 - Boss run finished. Total time: 40.08 s, Average time: 40.08 s

# %%
output_folder = "tests/assets/prize_counter_price_location/"
resolutions = [(1280, 720), (1024, 768), (1366, 768), (1600, 900), (1920, 1080)]
images_prefix = "prize_counter_price_location"
needle = "edmacro/assets/prize_counter_price_location.png"
bounds = [(0, 0, 1280, 720), (0, 0, 1024, 768), (0, 0, 1366, 768), (0, 0, 1600, 900), (0, 0, 1920, 1080)]

# utils.activate_roblox()
# time.sleep(3)
# ext.collect_screenshots(output_folder=output_folder, resolutions=resolutions, images_prefix=images_prefix, bound_areas=bounds, only_game_area=True)


ext.test_needles_in_different_haystacks(
    needle=needle,
    haystack_images_folder=output_folder,
    save_result=True,
    verbose=True
)
# Out:
# prize_counter_price_location_1024x768.png: 0.9277108907699585 at Rect(left=485, top=384, width=7, height=12)
# prize_counter_price_location_1280x720.png: 0.9021974205970764 at Rect(left=457, top=359, width=7, height=12)
# prize_counter_price_location_1366x768.png: 0.9277117848396301 at Rect(left=490, top=384, width=7, height=12)
# prize_counter_price_location_1600x900.png: 0.9385973811149597 at Rect(left=925, top=451, width=7, height=12)
# prize_counter_price_location_1920x1080.png: 1.0 at Rect(left=708, top=543, width=7, height=12)
# 0.004757385501630296

# %%
boss_health_images = [f for f in os.listdir(output_folder) if f.endswith(".png")]

fig, ax = plt.subplots(len(boss_health_images), 1, figsize=(20, 10))
for image in boss_health_images:
    img = cv2.imread(output_folder + image)
    width, height = img.shape[1], img.shape[0]
    y_start = int(height // 3)
    height = int(height * 0.4)
    y_end = y_start + height
    x_start = int(width // 3)
    width = int(width * 0.4)
    x_end = x_start + width
    img = img[y_start:y_end,x_start:x_end]


    ax[boss_health_images.index(image)].imshow(img)
    ax[boss_health_images.index(image)].set_title(boss_health_images.index(image))

fig.tight_layout()
plt.show()

# %%
img.shape
# Out:
# (432, 768, 3)

# %%
# Out:
# 2024-04-21 18:52:36.541 | DEBUG    | edmacro:__init__:32 - Config loaded
# 2024-04-21 18:52:36.546 | INFO     | edmacro:__init__:42 - MacroController initialized
# 2024-04-21 18:52:36.561 | DEBUG    | edmacro:__load_assets:69 - Loaded 28 assets.
# 2024-04-21 18:52:36.563 | INFO     | edmacro:__init__:45 - Assets loaded

# %%
import time

# %%
os.path.join(os.getcwd(),"edmacro/")
# Out:
# 'c:\\Users\\jedma\\dev\\edmacro\\edmacro\\edmacro/'

# %%
os.getcwd()
# Out:
# 'c:\\Users\\jedma\\dev\\edmacro\\edmacro'

# %%
# Out:
# 2024-04-21 19:03:55.127 | DEBUG    | edmacro:__init__:32 - Config loaded
# 2024-04-21 19:03:55.131 | INFO     | edmacro:__init__:42 - MacroController initialized
# 2024-04-21 19:03:55.142 | DEBUG    | edmacro:__load_assets:69 - Loaded 28 assets.
# 2024-04-21 19:03:55.143 | INFO     | edmacro:__init__:45 - Assets loaded
# 2024-04-21 19:04:00.669 | DEBUG    | edmacro:__init__:32 - Config loaded
# 2024-04-21 19:04:00.672 | INFO     | edmacro:__init__:42 - MacroController initialized
# 2024-04-21 19:04:00.684 | DEBUG    | edmacro:__load_assets:69 - Loaded 28 assets.
# 2024-04-21 19:04:00.685 | INFO     | edmacro:__init__:45 - Assets loaded
# 2024-04-21 19:04:05.699 | INFO     | edmacro.actions:open_map:120 - Opened map
# 2024-04-21 19:04:05.699 | WARNING  | edmacro.actions:move_to_map:222 - Warning! Current map is unknown. Brute forced back to map zero
# 2024-04-21 19:04:05.701 | INFO     | edmacro.actions:brute_force_back_to_map_zero:136 - Brute forcing back to map zero
# 2024-04-21 19:04:20.143 | INFO     | edmacro.actions:brute_force_back_to_map_zero:182 - Brute forced back to map zero
# 2024-04-21 19:04:20.144 | INFO     | edmacro.actions:move_to_map:232 - (0, 0) -> (2, 0): [('map_up', 2)]
# 2024-04-21 19:04:21.205 | INFO     | edmacro.actions:move_to_map:246 - Moved to map 2 column 0
# 2024-04-21 19:04:23.062 | INFO     | edmacro.actions:restart_char:53 - Restarting character
# 2024-04-21 19:04:25.805 | DEBUG    | edmacro.actions:restart_char:64 - The player wasnt respawned in the teleporter. Lets open the map and teleport him to same place.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 20
#      18 utils.activate_roblox()
#      19 mc = MacroController()
# ---> 20 mc.boss_run.execute(repeat=2, target_boss="KINGSLIME")
#
# File c:\Users\jedma\dev\edmacro\edmacro\actions\boss_run.py:62, in bossRunAction.execute(self, repeat, target_boss)
#      60 target_boss_map = self.BOSS_MAP[target_boss]
#      61 if self.macro_controller.current_map != target_boss_map:
# ---> 62     self.move_to_map(*target_boss_map)
#      64 self.target_boss = target_boss
#      65 self.macro_controller.logger.info(f"Running boss {repeat} times")
#
# File c:\Users\jedma\dev\edmacro\edmacro\actions\__init__.py:256, in Action.move_to_map(self, map_index, map_column)
#     253 time.sleep(1.5)
#     254 # then reset the char. We need this because the camera perspective changes
#     255 # when we teleport
# --> 256 self.restart_char()
#
# File c:\Users\jedma\dev\edmacro\edmacro\actions\__init__.py:67, in Action.restart_char(self)
#      63         raise RuntimeError("The player wasnt respawned in the teleporter and we dont know wich map he is. Aborting.")
#      64     self.macro_controller.logger.debug(
#      65         "The player wasnt respawned in the teleporter. Lets open the map and teleport him to same place."
#      66     )
# ---> 67     self.move_to_map(*self.macro_controller.current_map)
#      68 self.reset_camera()
#
# File c:\Users\jedma\dev\edmacro\edmacro\actions\__init__.py:220, in Action.move_to_map(self, map_index, map_column)
#     219 def move_to_map(self, map_index: int, map_column: int):
# --> 220     self.open_map()
#     221     if None in self.macro_controller.current_map:
#     222         self.macro_controller.logger.warning(
#     223             "Warning! Current map is unknown. Brute forced back to map zero"
#     224         )
#
# File c:\Users\jedma\dev\edmacro\edmacro\actions\__init__.py:119, in Action.open_map(self)
#     117     return
#     118 self._ahk.key_press("g")
# --> 119 time.sleep(5)
#     120 self.macro_controller.logger.info("Opened map")
#
# KeyboardInterrupt:
